# %% [markdown]
# <a href="https://colab.research.google.com/github/iypc-team/Reinforcement-Learning/blob/master/FrozenLake_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#. %pip install gym

print('\n', "All Installs Completed.")

# %%
import gym
import numpy as np
import random
import time
from IPython.display import clear_output
    
print("gym version:", gym.__version__)
print("numpy version:", np.__version__)

# %%
env = gym.make("FrozenLake-v0")

# %%
action_space_size = env.action_space.n
state_space_size = env.observation_space.n
q_table = np.zeros((state_space_size, action_space_size))

# %%
num_episodes = 10000
max_steps_per_episode = 100

exploration_rate = 1
max_exploration_rate = 1
min_exploration_rate = 0.01
exploration_decay_rate = 0.01
