// %% [markdown]
// <a href="https://colab.research.google.com/github/iypc-team/Reinforcement-Learning/blob/master/blank_swift.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

// %%
print("bullshit")
// Out:
// bullshit
