# %% [markdown]
# <a href="https://colab.research.google.com/github/iypc-team/Reinforcement-Learning/blob/master/Gym_Environment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
# %pip install gym
# %pip install pip
# %pip install tensorflow
# %pip install numpy
'''
from IPython.display import clear_output
clear_output(wait=False)

# %%
from __future__ import  absolute_import, division, print_function, unicode_literals 
import tensorflow as tf
from tensorflow import keras
import numpy as np
import gym
from gym import envs
  
clear_output(wait=False)
print("tf version:", tf.__version__)
print("keras version:",keras.__version__)
print("numpy version:", np.__version__)
print("gym version:", gym.__version__)

# %%
gym_dict = envs.registry.all()
for item in gym_dict:
  print('\n', item.id)
  print("max_steps:", item.max_episode_steps)
  print("timestep_limit:", item.timestep_limit)
  print("reward_threshold:", item.reward_threshold)
  print("trials:", item.trials)
  print()
  env = gym.make(item.id)
  env.reset()
  print("env.action_space:", env.action_space)
  print(env.unwrapped(all(iter)))
  print(env.compute_reward(achieved_goal=reward_range))
  print("env.reward_range:", env.reward_range)
  print("env.metadata:", env.metadata)

  env.close()
